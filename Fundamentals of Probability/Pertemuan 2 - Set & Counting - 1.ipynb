# %% [markdown]
# # Pertemuan 2 - Set and Counting
#
# Introduction to Probability Course

# %%
# import library

import matplotlib.pyplot as plt
import matplotlib_venn as venn

# %% [markdown]
# ## **Himpunan / Set**

# %% [markdown]
# ### **Notasi Himpunan**
# - Penulisan himpunan digunakan kurung kurawal
# <center>$A = \{1,2,3,4,5,6,7,\ldots\}$</center>
# - Himpunan dapat tidak memiliki isi
# - Dinamakan gimpunan kosong
# <center>$B = \{\}$</center>
# <center>$B = \emptyset$</center>

# %%
# Himpunan dengan isi 1 s.d. 7

A = {1,2,3,4,5,6,7}
type(A)
# Out:
# set

# %%
# Himpunan Kosong

B = set()
type(B)
# Out:
# set

# %% [markdown]
# Set dalam Python:

# %%
hewan = {'kucing', 'sapi', 'lele', 'ulat', 'ayam'}
hewan
# Out:
# {'ayam', 'kucing', 'lele', 'sapi', 'ulat'}

# %% [markdown]
# Elemen dalam sebuah set tidak bisa duplikat

# %%
hewan = {'kucing', 'kucing', 'sapi', 'lele', 'ulat', 'ayam'}
hewan
# Out:
# {'ayam', 'kucing', 'lele', 'sapi', 'ulat'}

# %% [markdown]
# Set tidak memperhatikan urutan

# %%
hewan = {'ulat', 'ayam', 'kucing', 'sapi', 'lele'}
hewan
# Out:
# {'ayam', 'kucing', 'lele', 'sapi', 'ulat'}

# %% [markdown]
# ## Elemen pada Himpunan

# %% [markdown]
# - Misal terdapat sebuah himpunan nama hari
# <center>$Hari = \{Senin, Selasa, Rabu, Kamis, Jumat, Sabtu, Minggu\}$</center>
# - Hari `Senin` merupakan anggota dari set `Hari`. Secara matematis dapat ditulis
# $$
# \text{Senin} \in \text{Hari}
# $$
# - Namun `Januari` bukan merupakan anggota dari set `Hari`
# $$
# \text{Januari} \notin \text{Hari}
# $$

# %%
Hari = {'Senin', 'Selasa', 'Rabu', 'Kamis', 'Jumat', 'Sabtu', 'Minggu'}

# %%
'Senin' in Hari
# Out:
# True

# %%
'Januari' in Hari
# Out:
# False

# %% [markdown]
# ### Menambah Elemen Baru

# %% [markdown]
# Untuk menambah elemen pada set kita dapat menggunakan perintah `add()`

# %%
basic_set = {1,2,3}
basic_set.add(5)
basic_set
# Out:
# {1, 2, 3, 5}

# %% [markdown]
# ## Menghapus Elemen

# %% [markdown]
# Untuk mengurangi elemen pada list, ada 2 perintah yang dapat kita gunakan:
# - `remove()`

# %%
basic_set = {1,2,3,4,5}
basic_set.remove(3)
basic_set.remove(5)
basic_set
# Out:
# {1, 2, 4}

# %% [markdown]
# ## Menghitung Jumlah Elemen

# %% [markdown]
# Notasi Jumlah Elemen:
#
# $$
# \text{Hari} = \{\text {Senin, Selasa, Rabu, Kamis, Jumat, Sabtu, Minggu}\}
# $$
# $$
# | \text{Hari} | = \text{7}
# $$

# %%
Hari
# Out:
# {'Jumat', 'Kamis', 'Minggu', 'Rabu', 'Sabtu', 'Selasa', 'Senin'}

# %%
len(Hari)
# Out:
# 7

# %%
hewan
# Out:
# {'ayam', 'kucing', 'lele', 'sapi', 'ulat'}

# %%
len(hewan)
# Out:
# 5

# %% [markdown]
# ## Diagram Venn

# %% [markdown]
# Diagram yang digunakan untuk menunjukkan relasi antar himpunan/set.
#
# Contoh: https://drive.google.com/uc?id=1hrSjAfBIAlxDSDVIafptYHsIdr2enBsv

# %%
Image("file/diagram_venn.png")

# %% [markdown]
# ## Operasi Himpunan / Set

# %% [markdown]
# ### Intersection

# %% [markdown]
# Fungsi `intersection()` digunakan untuk menghasilkan set baru yang berisi elemen yang sama dari kedua set

# %%
Image("file/intersection.png")

# %%
x_set = {1,2,3,4}
y_set = {3,4,5,6,7}

# %% [markdown]
# $ X = \{1,2,3,4\} $
#
# $ Y = \{3,4,5,6,7\} $
#
# $ X \cap Y = ? $

# %%
x_set.intersection(y_set)
# Out:
# {3, 4}

# %%
x_set & y_set
# Out:
# {3, 4}

# %%
y_set .intersection(x_set)
# Out:
# {3, 4}

# %%
y_set & x_set
# Out:
# {3, 4}

# %% [markdown]
# ### Union

# %% [markdown]
# Fungsi `union()` digunakan untuk menghasilkan set yang merupakan penggabungan dari kedua set

# %%
Image("file/union.png")

# %%
x_set = {1,2,3,4}
y_set = {3,4,5,6,7}

# %% [markdown]
# $X \cup Y = ?$

# %%
x_set.union(y_set)
# Out:
# {1, 2, 3, 4, 5, 6, 7}

# %%
x_set | y_set
# Out:
# {1, 2, 3, 4, 5, 6, 7}

# %%
y_set.union(x_set)
# Out:
# {1, 2, 3, 4, 5, 6, 7}

# %%
y_set | x_set
# Out:
# {1, 2, 3, 4, 5, 6, 7}

# %% [markdown]
# ### Difference / Komplemen

# %% [markdown]
# Fungsi `difference()` digunakan untuk menghasilkan set baru yang terdiri dari elemen yang tidak ada pada set lain

# %%
x_set = {1,2,3,4}
y_set = {3,4,5,6,7}

# %% [markdown]
# $ X - Y = ?$

# %%
x_set.difference(y_set)
# Out:
# {1, 2}

# %%
y_set.difference(x_set)
# Out:
# {5, 6, 7}

# %% [markdown]
# ### Subset & Superset

# %% [markdown]
# - Jika memiliki dua set: misal A dan B
# - Set B adalah subset dari A jika semua elemen B di A
#
# <center>$A = \{1,2,3,4,5,6,7\}$</center>
# <center>$B = \{1,3,5,7\}$</center>
# <center>$B \subset A $</center>
# <center>$A \supset B $</center>

# %%
A = {1,2,3,4,5,6,7}
B = {1,3,5}
C = {8,9,10}

# %%
venn.venn3([A, B, C], set_labels = ('A', 'B', 'C'))

plt.show()

# %% [markdown]
# is $B \subset A?$

# %%
B.issubset(A)
# Out:
# True

# %%
B.isdisjoint(A)
# Out:
# False

# %%
B.issuperset(A)
# Out:
# False

# %% [markdown]
# ## Case Diberikan

# %% [markdown]
# <center>$S = \{-1,0,1,2,3,4,5,20,90\}$</center>
# <center>$A = \{1,2,3,4,5\}$</center>
# <center>$B = \{0,2,-1,5,7\}$</center>
# <center>$C = \{20,90\}$</center>

# %% [markdown]
# **Maka Temukan:**
# 1. $|A|, |B|, |C|$ dan $|S|$
# 2. - $A \cap B$
#    - $A \cap C$
#    - $A \cap D$
#    - $A \cap S$
#    - $A \cup B$
#    - $A \cup C$
#    - $A \cup B \cup C$
#    - $A - C$
#    - $A - B$
#    - $A \subset B$
# 3. - $|A \cap B|$
#    - $|A \cup B \cup C|$

# %% [markdown]
# ## Answer

# %% [markdown]
# ### 1

# %%
S = {-1,0,1,2,3,4,5,20,90}
A = {1,2,3,4,5}
B = {0,2,-1,5,7}
C = {20,90}
D = {100}

# %%
venn.venn3([A, B, C], set_labels = ('A', 'B', 'C'))

plt.show()

# %% [markdown]
# $|A|$

# %%
len(A)
# Out:
# 5

# %% [markdown]
# $|B|$

# %%
len(B)
# Out:
# 5

# %% [markdown]
# $|S|$

# %%
len(C)
# Out:
# 2

# %% [markdown]
# $|S|$

# %%
len(S)
# Out:
# 9

# %% [markdown]
# ### 2

# %% [markdown]
# $A \cap B$

# %%
A.intersection(B)
# Out:
# {2, 5}

# %% [markdown]
# $A \cap C$

# %%
A.intersection(C)
# Out:
# set()

# %% [markdown]
# $A \cap D$

# %%
A.intersection(D)
# Out:
# set()

# %% [markdown]
# $A \cap S$

# %%
A.intersection(S)
# Out:
# {1, 2, 3, 4, 5}

# %% [markdown]
# $A \cup B$

# %%
A.union(B)
# Out:
# {-1, 0, 1, 2, 3, 4, 5, 7}

# %% [markdown]
# $A \cup C$

# %%
A.union(C)
# Out:
# {1, 2, 3, 4, 5, 20, 90}

# %% [markdown]
# $A \cup B \cup C$

# %%
A.union(B).union(C)
# Out:
# {-1, 0, 1, 2, 3, 4, 5, 7, 20, 90}

# %%
A.i
# Out:
# {-1, 0, 1, 2, 3, 4, 5, 20, 90}

# %% [markdown]
# $A - C$

# %%
A.difference(C)
# Out:
# {1, 2, 3, 4, 5}

# %% [markdown]
# $A - B$

# %%
A.difference(B)
# Out:
# {1, 3, 4}

# %% [markdown]
# ### 3

# %% [markdown]
# $|A \cap B|$

# %%
len(A.intersection(B))
# Out:
# 2

# %% [markdown]
# $|A \cup B \cup C|$

# %%
len(A.union(B).union(C))
# Out:
# 10

# %% [markdown]
# ### 4

# %% [markdown]
# $A^c$

# %%
S.difference(A)
# Out:
# {-1, 0, 20, 90}

# %% [markdown]
# $B^c$

# %%
S.difference(B)
# Out:
# {1, 3, 4, 20, 90}

# %% [markdown]
# $(A \cup B)^c$

# %%
len(S.difference(A.union(B)))
# Out:
# 2

# %% [markdown]
# $A^c \cap B^c$

# %%
len(S.difference(A).intersection(S.difference(B)))
# Out:
# 2

# %% [markdown]
# ### 5
